# %%
from time_tests import TimeTests

# %% [markdown]
# OLS
# ====

# %%
ols_tests = TimeTests(logit=False)
ols_tests.execute()
ols_tests.results
# Out:
#   Number_of_Rows  sklearn_mean_time  statsmodels_mean_time  t-statistic  \
# 0            100             0.0012                 0.0014      -0.1229
# 1           1000             0.0005                 0.0006      -1.8706
# 2          10000             0.0010                 0.0024      -6.8388
# 3         100000             0.0062                 0.0204     -18.3145
# 4        1000000             0.0937                 0.2647     -47.5592
# 5       10000000             1.0116                 2.7669     -40.6145
# 6      100000000            13.1914                45.7470     -26.4060
#
#    p-value Reject_Null
# 0   0.9036       False
# 1   0.0807       False
# 2   0.0000        True
# 3   0.0000        True
# 4   0.0000        True
# 5   0.0000        True
# 6   0.0000        True

# %% [markdown]
# Logistic Regression
# ====

# %%
logit_tests = TimeTests(logit=True)
logit_tests.execute()
logit_tests.results
# Out:
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669379
#          Iterations 4
# ...

# %%
logit_tests.results
# Out:
#   Number_of_Rows  sklearn_mean_time  statsmodels_mean_time  t-statistic  \
# 0            100             0.0043                 0.0039       0.2316
# 1           1000             0.0049                 0.0024       8.4438
# 2          10000             0.0045                 0.0056      -2.8583
# 3         100000             0.0744                 0.0442      18.8307
# 4        1000000             0.7637                 0.4280     119.9992
# 5       10000000             4.8613                 4.2705      45.2989
# 6      100000000            72.0735                58.9201     104.7029
#
#    p-value Reject_Null
# 0   0.8211       False
# 1   0.0000        True
# 2   0.0155       False
# 3   0.0000        True
# 4   0.0000        True
# 5   0.0000        True
# 6   0.0000        True
